# %%
from keras.datasets import imdb
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense, SimpleRNN, Embedding, Flatten

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=20000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((25000,), (25000,), (25000,), (25000,))

# %%
X_train = pad_sequences(X_train, padding='post', maxlen=200)
X_test = pad_sequences(X_test, padding='post', maxlen=200)

# %%
X_train.shape
# Out:
# (25000, 200)

# %%
model = Sequential([
    Embedding(10000, 256),
    SimpleRNN(128, return_sequences=True, dropout=0.2),
    SimpleRNN(64, dropout=0.2),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.4964 - loss: 0.7063 - val_accuracy: 0.5115 - val_loss: 0.6934
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.5004 - loss: 0.6958 - val_accuracy: 0.5083 - val_loss: 0.6933
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.5106 - loss: 0.6932 - val_accuracy: 0.4977 - val_loss: 0.6956
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.5330 - loss: 0.6822 - val_accuracy: 0.5458 - val_loss: 0.6780
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.5741 - loss: 0.6603 - val_accuracy: 0.5608 - val_loss: 0.6731
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 39ms/step - accuracy: 0.6162 - loss: 0.6056 - val_accuracy: 0.5784 - val_loss: 0.6577
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6345 - loss: 0.5894 - val_accuracy: 0.5824 - val_loss: 0.6783
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6580 - loss: 0.5604 - val_accuracy: 0.5750 - val_loss: 0.6942
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6388 - loss: 0.5684 - val_accuracy: 0.5702 - val_loss: 0.6927
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6560 - loss: 0.5453 - val_accuracy: 0.6000 - val_loss: 0.6874
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6688 - loss: 0.5320 - val_accuracy: 0.5658 - val_loss: 0.7096
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6718 - loss: 0.5294 - val_accuracy: 0.5683 - val_loss: 0.6926
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6645 - loss: 0.5345 - val_accuracy: 0.5640 - val_loss: 0.7515
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6390 - loss: 0.5650 - val_accuracy: 0.5795 - val_loss: 0.7114
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6486 - loss: 0.5526 - val_accuracy: 0.5666 - val_loss: 0.7262
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6501 - loss: 0.5424 - val_accuracy: 0.5693 - val_loss: 0.7294
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6610 - loss: 0.5303 - val_accuracy: 0.5790 - val_loss: 0.7213
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6532 - loss: 0.5446 - val_accuracy: 0.5501 - val_loss: 0.7359
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6578 - loss: 0.5404 - val_accuracy: 0.5770 - val_loss: 0.7205
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 39ms/step - accuracy: 0.6539 - loss: 0.5431 - val_accuracy: 0.5720 - val_loss: 0.7153
